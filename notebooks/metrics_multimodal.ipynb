# %%
import pandas as pd
import sys
import os
import pickle
sys.path.append('../')
from evaluation_metrics import (
    calculate_precision_at_k,
    calculate_average_precision_at_k,
    calculate_custom_precision_at_k,
    calculate_average_custom_precision_at_k)

# %%
# Load df metrics from pkl with list of dicts
with open('../../data/_multimodal_search_results.pkl', "rb") as f:
    data = pickle.load(f)

df_metrics = pd.DataFrame(data)

# %%
df_metrics
# Out:
#                 models_used use_bpr   fusion_method  reg_lambda   avg_mrr  \
# 0                       bpr     bpr          concat       0.005  0.118386
# 1                       bpr     bpr  by_autoencoder       0.005  0.129695
# 2                       bpr  binary          concat       0.000  0.145908
# 3                       bpr  binary  by_autoencoder       0.000  0.152781
# 4                     graph     bpr          concat       0.005  0.111326
# 5                     graph     bpr  by_autoencoder       0.005  0.113473
# 6                     graph  binary          concat       0.000  0.151387
# 7                     graph  binary  by_autoencoder       0.000  0.167570
# 8                      text     bpr          concat       0.005  0.147535
# 9                      text     bpr  by_autoencoder       0.005  0.172539
# 10                     text  binary          concat       0.000  0.174071
# 11                     text  binary  by_autoencoder       0.000  0.202572
# ...
